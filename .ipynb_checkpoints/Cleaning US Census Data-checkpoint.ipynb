# %% [markdown]
# # Cleaning US Census Data

# %% [markdown]
# You just got hired as a Data Analyst at the Census Bureau, which collects census data and creates interesting visualizations and insights from it.
#
# The person who had your job before you left you all the data they had for the most recent census. It is in multiple `csv` files. They didn't use pandas, they would just look through these `csv` files manually whenever they wanted to find something. Sometimes they would copy and paste certain numbers into Excel to make charts.
#
# The thought of it makes you shiver. This is not scalable or repeatable.
#
# Your boss wants you to make some scatterplots and histograms by the end of the day. Can you get this data into `pandas` and into reasonable shape so that you can make these histograms?

# %% [markdown]
# ## Inspect the Data!

# %% [markdown]
# 1. The first visualization your boss wants you to make is a scatterplot that shows average income in a state vs proportion of women in that state.
#
#    Open some of the census `csv` files that came with the kit you downloaded. How are they named? What kind of information do they hold? Will they help us make this graph?

# %%
import pandas as pd
df = pd.read_csv("resources/states0.csv")
print(df.head(50))
# Out:
#    Unnamed: 0       State  TotalPop Hispanic   White   Black  Native   Asian  \
# 0           0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%
# 1           1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%
# 2           2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%
# 3           3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%
# 4           4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%
# 5           5    Colorado   5278906   20.78%  69.90%   3.55%   0.57%   2.66%
#
#   Pacific       Income            GenderPop
# 0   0.03%  $43,296.36     2341093M_2489527F
# 1   1.06%  $70,354.74       384160M_349215F
# 2   0.17%  $54,207.82     3299088M_3342840F
# 3   0.15%  $41,935.63     1451913M_1506295F
# 4   0.35%  $67,264.78   19087135M_19334329F
# 5     NaN  $64,657.80     2648667M_2630239F

# %% [markdown]
# 2. It will be easier to inspect this data once we have it in a DataFrame. You can't even call `.head()` on these `csv`s! How are you supposed to read them?
#
#    Using `glob`, loop through the census files available and load them into DataFrames. Then, concatenate all of those DataFrames together into one DataFrame, called something like `us_census`.

# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
import glob

all_csvs = glob.glob("resources/*.csv")
states_df = []
for csv_file in all_csvs:
    df = pd.read_csv(csv_file)
    states_df.append(df)
us_census = pd.concat(states_df, axis=0, ignore_index=True)

# %%
us_census.head(10)
# Out:
#    Unnamed: 0          State  TotalPop Hispanic   White   Black Native  Asian  \
# 0           0       Missouri   6045448    4.04%  77.51%  14.12%  0.36%  1.62%
# 1           1        Montana   1014699    3.27%  86.42%   0.43%  7.06%  0.57%
# 2           2       Nebraska   1869365    9.20%  81.14%   4.96%  0.86%  1.86%
# 3           3         Nevada   2798636   27.10%  53.24%   7.74%  1.09%  7.10%
# 4           4  New Hampshire   1324201    3.32%  91.32%   1.23%  0.14%  2.19%
# 5           5     New Jersey   8904413   18.75%  56.49%  14.39%  0.12%  8.16%
# 6           0           Iowa   3093526    5.30%  87.72%   3.26%  0.29%  1.70%
# 7           1         Kansas   2892987   11.64%  75.96%   6.57%  0.73%  2.33%
# 8           2       Kentucky   4397353    3.22%  85.23%   8.27%  0.17%  1.13%
# 9           3      Louisiana   4625253    4.87%  54.98%  36.33%  0.48%  1.67%
#
#   Pacific       Income          GenderPop
# 0   0.10%  $49,763.99   2964003M_3081445F
# ...

# %% [markdown]
# 3. Look at the `.columns` and the `.dtypes` of the `us_census` DataFrame. Are those datatypes going to hinder you as you try to make histograms?

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
us_census.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %% [markdown]
# 4. Look at the `head()` of the DataFrame so that you can understand why some of these `dtypes` are objects instead of integers or floats.
#
#    Start to make a plan for how to convert these columns into the right types for manipulation.

# %%
us_census.head()
# Out:
#    Unnamed: 0          State  TotalPop Hispanic   White   Black Native  Asian  \
# 0           0       Missouri   6045448    4.04%  77.51%  14.12%  0.36%  1.62%
# 1           1        Montana   1014699    3.27%  86.42%   0.43%  7.06%  0.57%
# 2           2       Nebraska   1869365    9.20%  81.14%   4.96%  0.86%  1.86%
# 3           3         Nevada   2798636   27.10%  53.24%   7.74%  1.09%  7.10%
# 4           4  New Hampshire   1324201    3.32%  91.32%   1.23%  0.14%  2.19%
#
#   Pacific       Income          GenderPop
# 0   0.10%  $49,763.99   2964003M_3081445F
# 1   0.07%  $47,645.68           510163M_F
# 2   0.06%  $55,916.47     929606M_939759F
# 3   0.57%  $55,526.53   1407735M_1390901F
# 4   0.02%  $68,728.86     653484M_670717F

# %% [markdown]
# ## Regex to the Rescue

# %% [markdown]
# 5. Use regex to turn the `Income` column into a format that is ready for conversion into a numerical type.

# %%
income_series = us_census.Income.str.split("(\$)")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipykernel_1144780/1490742095.py:1: SyntaxWarning: invalid escape sequence '\$'
#   income_series = us_census.Income.str.split("(\$)")

# %%
income_series.head()
# Out:
# 0    [, $, 49,763.99 ]
# 1    [, $, 47,645.68 ]
# 2    [, $, 55,916.47 ]
# 3    [, $, 55,526.53 ]
# 4    [, $, 68,728.86 ]
# Name: Income, dtype: object

# %%
income_series[1][2].strip()
# Out:
# '47,645.68'

# %%
us_census = us_census.rename(columns={"Income": "Income [$]"})
# us_census["Income [$]"] = us_census["Income [$]"].str.replace("$", "").str.replace(",", "").str.strip()
us_census["Income [$]"] = us_census["Income [$]"].str.replace("[\$|,]", "", regex=True).str.strip()

us_census.head()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipykernel_1144780/475458123.py:3: SyntaxWarning: invalid escape sequence '\$'
#   us_census["Income [$]"] = us_census["Income [$]"].str.replace("[\$|,]", "", regex=True).str.strip()
#    Unnamed: 0          State  TotalPop Hispanic   White   Black Native  Asian  \
# 0           0       Missouri   6045448    4.04%  77.51%  14.12%  0.36%  1.62%
# 1           1        Montana   1014699    3.27%  86.42%   0.43%  7.06%  0.57%
# 2           2       Nebraska   1869365    9.20%  81.14%   4.96%  0.86%  1.86%
# 3           3         Nevada   2798636   27.10%  53.24%   7.74%  1.09%  7.10%
# 4           4  New Hampshire   1324201    3.32%  91.32%   1.23%  0.14%  2.19%
#
#   Pacific Income [$]          GenderPop
# 0   0.10%   49763.99  2964003M_3081445F
# 1   0.07%   47645.68          510163M_F
# 2   0.06%   55916.47    929606M_939759F
# 3   0.57%   55526.53  1407735M_1390901F
# ...

# %%
us_census.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income [$]    object
# GenderPop     object
# dtype: object

# %%
us_census["Income [$]"] = pd.to_numeric(us_census["Income [$]"])
us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic       object
# White          object
# Black          object
# Native         object
# Asian          object
# Pacific        object
# Income [$]    float64
# GenderPop      object
# dtype: object

# %% [markdown]
# 6. Look at the `GenderPop` column. We are going to want to separate this into two columns, the `Men` column, and the `Women` column.
#
#    Split the column into those two new columns using `str.split` and separating out those results.

# %%
us_census.GenderPop.head()
# Out:
# 0    2964003M_3081445F
# 1            510163M_F
# 2      929606M_939759F
# 3    1407735M_1390901F
# 4      653484M_670717F
# Name: GenderPop, dtype: object

# %%
split_gender_pop = us_census.GenderPop.str.replace("M|F", "", regex=True).str.split("_", expand=True)
split_gender_pop.head()
# Out:
#          0        1
# 0  2964003  3081445
# 1   510163
# 2   929606   939759
# 3  1407735  1390901
# 4   653484   670717

# %%
split_gender_pop[1].head()
# Out:
# 0    3081445
# 1
# 2     939759
# 3    1390901
# 4     670717
# Name: 1, dtype: object

# %%
us_census["Men"] = split_gender_pop[0]
us_census["Women"] = split_gender_pop[1]
us_census.head()
# Out:
#    Unnamed: 0          State  TotalPop Hispanic   White   Black Native  Asian  \
# 0           0       Missouri   6045448    4.04%  77.51%  14.12%  0.36%  1.62%
# 1           1        Montana   1014699    3.27%  86.42%   0.43%  7.06%  0.57%
# 2           2       Nebraska   1869365    9.20%  81.14%   4.96%  0.86%  1.86%
# 3           3         Nevada   2798636   27.10%  53.24%   7.74%  1.09%  7.10%
# 4           4  New Hampshire   1324201    3.32%  91.32%   1.23%  0.14%  2.19%
#
#   Pacific  Income [$]          GenderPop      Men    Women
# 0   0.10%    49763.99  2964003M_3081445F  2964003  3081445
# 1   0.07%    47645.68          510163M_F   510163
# 2   0.06%    55916.47    929606M_939759F   929606   939759
# 3   0.57%    55526.53  1407735M_1390901F  1407735  1390901
# 4   0.02%    68728.86    653484M_670717F   653484   670717

# %%
us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic       object
# White          object
# Black          object
# Native         object
# Asian          object
# Pacific        object
# Income [$]    float64
# GenderPop      object
# Men            object
# Women          object
# dtype: object

# %% [markdown]
# 7. Convert both of the columns into numerical datatypes.
#
#    There is still an `M` or an `F` character in each entry! We should remove those before we convert.

# %%
us_census.Men = pd.to_numeric(us_census.Men)
us_census.Women = pd.to_numeric(us_census.Women)
us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic       object
# White          object
# Black          object
# Native         object
# Asian          object
# Pacific        object
# Income [$]    float64
# GenderPop      object
# Men             int64
# Women         float64
# dtype: object

# %% [markdown]
# 8. Now you should have the columns you need to make the graph and make sure your boss does not slam a ruler angrily on your desk because you've wasted your whole day cleaning your data with no results to show!
#
#    Use matplotlib to make a scatterplot!
#
#    ```py
#    plt.scatter(the_women_column, the_income_column)
#    ```
#
#    Remember to call `plt.show()` to see the graph!

# %%
import matplotlib.pyplot as plt

plt.scatter(us_census.Women, us_census["Income [$]"])
plt.show()

# %% [markdown]
# 9. You want to double check your work. You know from experience that these monstrous csv files probably have `nan` values in them! Print out your column with the number of women per state to see.
#
#    We can fill in those `nan`s by using pandas' `.fillna()` function.
#
#    You have the `TotalPop` per state, and you have the `Men` per state. As an estimate for the `nan` values in the `Women` column, you could use the `TotalPop` of that state minus the `Men` for that state.
#
#    Print out the `Women` column after filling the `nan` values to see if it worked!

# %%
us_census[["State", "Women"]].head()
# Out:
#            State      Women
# 0       Missouri  3081445.0
# 1        Montana   504536.0
# 2       Nebraska   939759.0
# 3         Nevada  1390901.0
# 4  New Hampshire   670717.0

# %%
us_census.Women = us_census.Women.fillna(value=us_census.TotalPop - us_census.Men)
us_census[["State", "Women"]].head()
# Out:
#            State      Women
# 0       Missouri  3081445.0
# 1        Montana   504536.0
# 2       Nebraska   939759.0
# 3         Nevada  1390901.0
# 4  New Hampshire   670717.0

# %% [markdown]
# 10. We forgot to check for duplicates! Use `.duplicated()` on your `census` DataFrame to see if we have duplicate rows in there.

# %%
us_census.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %% [markdown]
# 11. Drop those duplicates using the `.drop_duplicates()` function.

# %%
us_census.drop_duplicates()
# Out:
#     Unnamed: 0                 State  TotalPop Hispanic   White   Black  \
# 0            0              Missouri   6045448    4.04%  77.51%  14.12%
# 1            1               Montana   1014699    3.27%  86.42%   0.43%
# 2            2              Nebraska   1869365    9.20%  81.14%   4.96%
# 3            3                Nevada   2798636   27.10%  53.24%   7.74%
# 4            4         New Hampshire   1324201    3.32%  91.32%   1.23%
# 5            5            New Jersey   8904413   18.75%  56.49%  14.39%
# 6            0                  Iowa   3093526    5.30%  87.72%   3.26%
# 7            1                Kansas   2892987   11.64%  75.96%   6.57%
# 8            2              Kentucky   4397353    3.22%  85.23%   8.27%
# 9            3             Louisiana   4625253    4.87%  54.98%  36.33%
# 10           4                 Maine   1329100    1.43%  93.71%   1.13%
# 11           5              Maryland   5930538    8.47%  52.68%  30.68%
# ...

# %% [markdown]
# 12. Make the scatterplot again. Now, it should be perfect! Your job is secure, for now.

# %%
plt.clf()
plt.scatter(us_census.Women, us_census["Income [$]"])
plt.show()

# %% [markdown]
# ## Histogram of Races

# %% [markdown]
# 13. Now your boss wants you to make a bunch of histograms out of the race data that you have. Look at the `.columns` again to see what the race categories are.

# %%
us_census.head(5)
# Out:
#    Unnamed: 0          State  TotalPop Hispanic   White   Black Native  Asian  \
# 0           0       Missouri   6045448    4.04%  77.51%  14.12%  0.36%  1.62%
# 1           1        Montana   1014699    3.27%  86.42%   0.43%  7.06%  0.57%
# 2           2       Nebraska   1869365    9.20%  81.14%   4.96%  0.86%  1.86%
# 3           3         Nevada   2798636   27.10%  53.24%   7.74%  1.09%  7.10%
# 4           4  New Hampshire   1324201    3.32%  91.32%   1.23%  0.14%  2.19%
#
#   Pacific  Income [$]          GenderPop      Men      Women
# 0   0.10%    49763.99  2964003M_3081445F  2964003  3081445.0
# 1   0.07%    47645.68          510163M_F   510163   504536.0
# 2   0.06%    55916.47    929606M_939759F   929606   939759.0
# 3   0.57%    55526.53  1407735M_1390901F  1407735  1390901.0
# 4   0.02%    68728.86    653484M_670717F   653484   670717.0

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income [$]', 'GenderPop', 'Men',
#        'Women'],
#       dtype='object')

# %%
us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic       object
# White          object
# Black          object
# Native         object
# Asian          object
# Pacific        object
# Income [$]    float64
# GenderPop      object
# Men             int64
# Women         float64
# dtype: object

# %% [markdown]
# 14. Try to make a histogram for each one!
#
#     You will have to get the columns into the numerical format, and those percentage signs will have to go.
#
#     Don't forget to fill the `nan` values with something that makes sense! You probably dropped the duplicate rows when making your last graph, but it couldn't hurt to check for duplicates again.

# %%
races = ["Hispanic", "White", "Black", "Native", "Asian", "Pacific"]
for race_col in races:
    us_census[race_col] = us_census[race_col].str.replace("%", "").str.strip()
    us_census[race_col] = pd.to_numeric(us_census[race_col])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 3
#       1 races = ["Hispanic", "White", "Black", "Native", "Asian", "Pacific"]
#       2 for race_col in races:
# ----> 3     us_census[race_col] = us_census[race_col].str.replace("%", "").str.strip()
#       4     us_census[race_col] = pd.to_numeric(us_census[race_col])
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# ...

# %%
us_census.head(5)
# Out:
#    Unnamed: 0          State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0           0       Missouri   6045448      4.04  77.51  14.12    0.36   1.62
# 1           1        Montana   1014699      3.27  86.42   0.43    7.06   0.57
# 2           2       Nebraska   1869365      9.20  81.14   4.96    0.86   1.86
# 3           3         Nevada   2798636     27.10  53.24   7.74    1.09   7.10
# 4           4  New Hampshire   1324201      3.32  91.32   1.23    0.14   2.19
#
#    Pacific  Income [$]          GenderPop      Men      Women
# 0     0.10    49763.99  2964003M_3081445F  2964003  3081445.0
# 1     0.07    47645.68          510163M_F   510163   504536.0
# 2     0.06    55916.47    929606M_939759F   929606   939759.0
# 3     0.57    55526.53  1407735M_1390901F  1407735  1390901.0
# 4     0.02    68728.86    653484M_670717F   653484   670717.0

# %%
us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic      float64
# White         float64
# Black         float64
# Native        float64
# Asian         float64
# Pacific       float64
# Income [$]    float64
# GenderPop      object
# Men             int64
# Women         float64
# dtype: object

# %%
us_census[races].duplicated().sum()
# Out:
# 8

# %%
us_census[races] = us_census[races].drop_duplicates()

# %%
census = us_census.drop_duplicates(subset = us_census.columns[1:])

# %%
us_census.duplicated(subset = us_census.columns[1:]).sum()
# Out:
# 0

# %%
us_census[races] = us_census[races].fillna(value=0)

# %%
plt.clf()
for race in races:
    plt.hist(us_census[race])
    plt.title("Histogram of the Percentage of {} People per State".format(race))
    # plt.xlabel("Percentage")
    # plt.ylabel("Frequency")
    plt.show()
    plt.clf()

# %% [markdown]
# # Get Creative

# %% [markdown]
# 15. Phew. You've definitely impressed your boss on your first day of work.
#
#     But is there a way you really convey the power of pandas and Python over the drudgery of `csv` and Excel?
#
#     Try to make some more interesting graphs to show your boss, and the world! You may need to clean the data even more to do it, or the cleaning you have already done may give you the ease of manipulation you've been searching for.
